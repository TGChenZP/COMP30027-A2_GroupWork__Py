# %% [markdown]
# # 3. Tuning Evaluation (for Tuning part 1 output)

# %%
import pandas as pd

# %% [markdown]
# Please adjust this cell to change files to be viewed

# %%
MODEL_NAME = 'RF'
DTYPE = 'TFIDF_Preprocessed'

# %%
file = pd.read_csv(f'./Tuning/Tuning - {MODEL_NAME} {DTYPE}.csv')

# %%
# View tuning results
file.sort_values(by = 'accuracy', ascending = False).head(60)
# Out:
#        gamma  sub_sample  col_sample_by_tree  max_depth   eta     fs  accuracy
# 6098    0.01        0.75                0.75         10  0.25  17434  0.674006
# 16800   1.00        0.50                0.50          6  0.25   9434  0.672477
# 5427    0.01        0.75                0.25         10  0.30   9434  0.672171
# 13740   0.50        0.50                0.50          6  0.25   9434  0.671865
# 15213   0.50        0.75                0.75          8  0.30  20434  0.671865
# 17235   1.00        0.50                0.75          8  0.25  19434  0.671254
# 10697   0.10        0.50                0.50          6  0.30   9434  0.671254
# 6117    0.01        0.75                0.75         10  0.30  19434  0.671254
# 6102    0.01        0.75                0.75         10  0.25  21434  0.670336
# 17845   1.00        0.75                0.50          6  0.30  17434  0.670336
# 18351   1.00        0.75                0.75         10  0.30  13434  0.670336
# ...
